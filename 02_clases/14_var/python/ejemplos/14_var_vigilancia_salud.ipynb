# %% [markdown]
# <div style="text-align: center; color:rgb(0, 0, 0); font-family: Arial, sans-serif; background-color:rgb(137, 200, 129); padding: 10px; border-radius: 10px; box-shadow: 0 4px 8px rgba(0, 0, 0, 1.2); line-height: 0.1;">
#
# ### **Series de Tiempo**
# #### **Universidad Central**
# #### Maestría en Analítica de Datos
# #### Docente: Wilson Sandoval Rodriguez
# ##### wsandovalr@ucentral.edu.co
#
# </div>

# %% [markdown]
# ## Vector autoregresivo VAR(p)
# - Un modelo VAR (vector autoregresivo) es generalmente utilizado cuando se desean encontrar relaciones simultaneas en un grupo de variables, permitiendo así estimar un sistema de ecuaciones, a diferencia de los modelos ARIMA tradicionales que permiten estimar sólo una ecuación.
#
# - El modelo VAR es especialmente útil cuando las relaciones entre variables se transmiten a varios periodos, corrigiendo los problemas de endogeneidad (simultaneidad entre variables) y mostrando la interrelación dinámica que hay entre las variables estacionarias.
#
# - El modelo VAR, propuesto por Christopher Sims en 1980, es una extensión multivariada de los modelos autorregresivos univariados. En un VAR, cada variable es una función lineal de sus propios valores rezagados y de los rezagos de todas las demás variables en el sistema.
#
# **Características Clave:**
#
# Simplicidad: Todos los variables son tratadas simétricamente sin necesidad de distinguir entre variables endógenas y exógenas.
#
# Flexibilidad: Capaz de capturar relaciones dinámicas complejas.
#
# Aplicabilidad: Utilizado en economía, finanzas, meteorología y otras disciplinas.

# %% [markdown]
# ## Modelo VAR($p$)
#
# La serie multivariada  $\boldsymbol{z_t}$ sigue un modelo  VAR de orden $p$, VAR($p$), si
#
# $$\boldsymbol{z}_{t}=\phi_{0}+\sum_{i=1}^{p} \phi_{i} z_{t-i}+\boldsymbol{a}_{t}$$
#
# - $\phi_0$:= es una constante de dimensión $k$
#
# - $\phi_i$  son matrices de  $k \times k$  para $i > 0$,  $\phi_p \neq \boldsymbol{0}$
#
# - $\boldsymbol{a_t}$ es una sucesión  de vectores aleatorios independientes e identicamente distribuidos (iid) con media cero y matriz de covarianza $\sum_a$ definida positiva.

# %% [markdown]
# ## VAR($1$)
#
#
# $$\boldsymbol{z}_{t}=\boldsymbol{\phi}_{0}+\boldsymbol{\phi}_{1} \boldsymbol{z}_{t-1}+\boldsymbol{a}_{t}$$
#
# Escribiendo el modelo explicitamente se tiene:
#
#
# $$\begin{pmatrix} z_{1t} \\
# z_{2t}
# \end{pmatrix}
# =
# \begin{pmatrix}
# \phi_{10} \\
# \phi_{20}
# \end{pmatrix}
# +
# \begin{pmatrix}
# \phi_{1,11} & \phi_{1,12} \\
# \phi_{2,11} & \phi_{2,12}
# \end{pmatrix}
# \begin{pmatrix}
# z_{1,t-1} \\
# z_{2,t-1}
# \end{pmatrix}
# +
# \begin{pmatrix}
# a_{1t} \\
# a_{2t}
# \end{pmatrix}$$
#
#
#
#
#
# $$\begin{array}{l}
# z_{1 t}=\phi_{10}+\phi_{1,11} z_{1, t-1}+\phi_{1,12} z_{2, t-1}+a_{1 t} \\
# z_{2 t}=\phi_{20}+\phi_{1,21} z_{1, t-1}+\phi_{1,22} z_{2, t-1}+a_{2 t}
# \end{array}$$
#
#
# - Las ecuaciones muestran que la variable $z_{1t}$ es explicada por rezagos de $z_{2t}$ y de sí misma; y de igual manera la variable $z_{2t}$ es afectada por rezagos de $z_{1t}$ y de sí misma, de manera que no es posible distinguir entre variables endógenas y variables exógenas .
#
# - Un VAR($1$) se refiere a un modelo cuyo máximo rezago es $1$.

# %% [markdown]
# ## Notas
#
# - En otras palabras, bajo el marco de Granger, decimos
# que $z_{1t}$ causa $z_{2t}$ si la información pasada de $z_{1t}$ mejora el pronóstico de $z_{2t}$
#
# - Para el modelo bivariado VAR(1) en la ecuación,  si $\sum_a$ no es una matriz diagonal, entonces $z_{1t}$ y $z_{2t}$ se correlacionan instantáneamente (o contemporáneamente
# correlacionado).
# - En este caso, $z_{1t}$ y $z_{2t}$ tienen causalidad de Granger instantánea. La causalidad instantánea va en ambos sentidos.

# %% [markdown]
# ## Construir el Modelo
#
# Seguir el procedimiento iterativo de Box y Jenkins
#
# - Especificación,
# - Estimación,
# - Diagnostico

# %% [markdown]
# ## Estimado el VAR(p), el usuario estará interesado en alguno de los siguientes elementos
#
# - Comprender la dinámica entre las variables parte del análisis
# - Análisis de causalidad
# - Análisis de Impulso Respuesta
# - Pronosticar fuera de la muestra
# - Descomposición del Error de pronóstico
# - Análisis de diagnóstico

# %% [markdown]
# ## Orden de Selección
#
# - Test de razones de verosimilitud
# - Criterios de Información
#
# $$\begin{array}{l}
# \operatorname{AIC}(\ell)=\ln \left|\hat{\mathbf{\Sigma}}_{a, \ell}\right|+\frac{2}{T} \ell k^{2} \\
# \operatorname{BIC}(\ell)=\ln \left|\hat{\mathbf{\Sigma}}_{a, \ell}\right|+\frac{\ln (T)}{T} \ell k^{2} \\
# \operatorname{HQ}(\ell)=\ln \left|\hat{\mathbf{\Sigma}}_{a, \ell}\right|+\frac{2 \ln [\ln (T)]}{T} \ell k^{2}
# \end{array}$$
#
#
# ## Test de Correlación Serial
#
# - Test de Portmanteau
# - Test de Breusch-Godfrey

# %% [markdown]
# ## Causalidad
# - El test de causalidad se debe a los desarrollos de
# Granger(1969). “Investigating causal relations by econometric
# models and cross-sprectral methods”. Econometrika 46,
# 1303-1310.
# -  Una variable X causa en el sentido de Granger a otra Y, si
# la variable X ayuda a predecir la variableY
#
# - R tiene implementado dos pruebas:
#   - Test de causalidad de Granger
#   - Test de causalidad instantánea
#
#
# $$H_0: \   X_t \  \  \text{no causa en el sentido de Granger a} \ \  Y_t $$

# %% [markdown]
# ### Limitaciones:
#
# Necesidad de Estacionariedad: Las series deben ser estacionarias o transformadas adecuadamente.
#
# Complejidad con Altos Rezagos: El número de parámetros a estimar crece rápidamente con 𝑝  y 𝑘.
#
# Interpretación: Puede ser difícil interpretar los coeficientes individuales.

# %% [markdown]
# ---
# ## Aplicación Práctica: VAR con Casos de Asma, PM2.5, Temperatura y Precipitación
#
# Se modela el sistema multivariado con datos diarios de Bogotá (2023-2024).
# Variables: **asma** (casos diarios), **PM2.5** (µg/m³), **temperatura** (°C), **precipitación** (mm).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy import stats
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller, kpss
import warnings
warnings.filterwarnings('ignore')

plt.rcParams.update({
    'figure.dpi': 110,
    'axes.grid': True,
    'grid.alpha': 0.3,
    'font.size': 11,
    'axes.spines.top': False,
    'axes.spines.right': False,
})

# %% [markdown]
# ### 1. Carga y limpieza de datos

# %%
url = "https://github.com/Wilsonsr/Series-de-Tiempo/raw/main/03_datos/14_var/vigilancia_centinela.xlsx"
raw = pd.read_excel(url)

# Seleccionar y renombrar solo las cuatro variables de interes
df = raw[['fecha', 'asma ', 'pm2.5', 'temperatura', 'precipitacion ']].copy()
df.columns = ['fecha', 'asma', 'pm25', 'temperatura', 'precipitacion']
df['fecha'] = pd.to_datetime(df['fecha'])
df = df.set_index('fecha').asfreq('D')

print(f"Periodo      : {df.index[0].date()} - {df.index[-1].date()}")
print(f"Observaciones: {len(df)}")
print(f"Valores nulos: {df.isna().sum().sum()}")
df.describe().round(2)
# Out:
# Periodo      : 2023-01-01 - 2024-04-06
# Observaciones: 462
# Valores nulos: 0
#          asma    pm25  temperatura  precipitacion
# count  462.00  462.00       462.00         462.00
# mean     5.53   17.00        15.48           2.32
# std      3.44    7.84         0.85           4.43
# min      0.00    3.90        12.62           0.00
# 25%      3.00   10.99        14.94           0.01
# 50%      5.00   15.53        15.53           0.36
# 75%      7.75   22.26        16.06           2.68
# max     19.00   47.81        17.57          30.98

# %% [markdown]
# ### 2. Visualización de las series temporales

# %%
etiquetas = [
    ('asma',          'Casos de Asma (diarios)', 'steelblue'),
    ('pm25',          'PM2.5 (ug/m3)',            'firebrick'),
    ('temperatura',   'Temperatura (C)',          'darkorange'),
    ('precipitacion', 'Precipitacion (mm)',       'seagreen'),
]

fig, axes = plt.subplots(4, 1, figsize=(13, 10), sharex=True)
for ax, (col, titulo, color) in zip(axes, etiquetas):
    ax.plot(df.index, df[col], color=color, linewidth=0.85, alpha=0.9)
    ax.set_ylabel(titulo, fontsize=10)
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))

axes[-1].set_xlabel('Fecha')
fig.suptitle('Sistema de Series de Tiempo  Bogota 2023-2024',
             fontsize=13, y=1.01, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Correlacion entre variables

# %%
corr = df.corr()
labels = ['Asma', 'PM2.5', 'Temperatura', 'Precipitacion']

fig, ax = plt.subplots(figsize=(6, 5))
im = ax.imshow(corr, cmap='RdYlGn', vmin=-1, vmax=1)
cbar = plt.colorbar(im, ax=ax, shrink=0.8)
cbar.set_label('Correlacion de Pearson')
ax.set_xticks(range(4)); ax.set_yticks(range(4))
ax.set_xticklabels(labels, rotation=30, ha='right')
ax.set_yticklabels(labels)
for i in range(4):
    for j in range(4):
        txt_color = 'white' if abs(corr.iloc[i, j]) > 0.6 else 'black'
        ax.text(j, i, f'{corr.iloc[i, j]:.2f}', ha='center', va='center',
                fontsize=11, color=txt_color, fontweight='bold')
ax.set_title('Matriz de Correlacion', fontsize=12, pad=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Pruebas de estacionariedad
#
# Se aplican dos pruebas complementarias:
# - **ADF** (Dickey-Fuller Aumentado): H₀ = raiz unitaria (no estacionaria).
# - **KPSS**: H₀ = estacionaria.
#
# Conclusion: serie estacionaria cuando **ADF rechaza H₀** (p < 0.05) **y KPSS no rechaza H₀** (p > 0.05).

# %%
def test_estacionariedad(series, nombre, alpha=0.05):
    adf_stat, adf_p, *_ = adfuller(series.dropna(), autolag='BIC')
    kpss_stat, kpss_p, *_ = kpss(series.dropna(), regression='c', nlags='auto')
    adf_ok  = adf_p < alpha
    kpss_ok = kpss_p > alpha
    concl = 'Estacionaria OK' if (adf_ok and kpss_ok) else 'Revisar [!]'
    print(f'{chr(9472)*60}')
    print(f' {nombre}')
    print(f'  ADF  -- estadistico: {adf_stat:8.4f}  p-valor: {adf_p:.4f}  '
          f"{'(Rechaza H0)' if adf_ok else '(No rechaza H0)'}")
    print(f'  KPSS -- estadistico: {kpss_stat:8.4f}  p-valor: {kpss_p:.4f}  '
          f"{'(No rechaza H0)' if kpss_ok else '(Rechaza H0)'}")
    print(f'  Conclusion: {concl}')

nombres = {'asma': 'Asma', 'pm25': 'PM2.5',
           'temperatura': 'Temperatura', 'precipitacion': 'Precipitacion'}
for col, nom in nombres.items():
    test_estacionariedad(df[col], nom)
print(f'{chr(9472)*60}')
# Out:
# ────────────────────────────────────────────────────────────
#  Asma
#   ADF  -- estadistico:  -3.0916  p-valor: 0.0272  (Rechaza H0)
#   KPSS -- estadistico:   0.6410  p-valor: 0.0189  (Rechaza H0)
#   Conclusion: Revisar [!]
# ────────────────────────────────────────────────────────────
#  PM2.5
#   ADF  -- estadistico:  -7.3560  p-valor: 0.0000  (Rechaza H0)
#   KPSS -- estadistico:   0.9967  p-valor: 0.0100  (Rechaza H0)
#   Conclusion: Revisar [!]
# ────────────────────────────────────────────────────────────
#  Temperatura
#   ADF  -- estadistico:  -6.5535  p-valor: 0.0000  (Rechaza H0)
#   KPSS -- estadistico:   2.3028  p-valor: 0.0100  (Rechaza H0)
#   Conclusion: Revisar [!]
# ────────────────────────────────────────────────────────────
#  Precipitacion
#   ADF  -- estadistico: -15.1993  p-valor: 0.0000  (Rechaza H0)
#   KPSS -- estadistico:   0.2554  p-valor: 0.1000  (No rechaza H0)
#   Conclusion: Estacionaria OK
# ...

# %% [markdown]
# ### 5. Seleccion del orden del modelo VAR(p)
#
# Se utilizan los criterios de informacion AIC, BIC y HQIC.
# Se prefiere **BIC** (penaliza mas la complejidad) para muestras de tamano moderado.

# %%
model = VAR(df)
lag_sel = model.select_order(maxlags=15)
print(lag_sel.summary())
p_opt = lag_sel.bic
print(f'\nRezago optimo BIC: {p_opt}  |  AIC: {lag_sel.aic}  |  HQIC: {lag_sel.hqic}')
print(f'Se usara p = {p_opt} (criterio BIC)')
# Out:
#  VAR Order Selection (* highlights the minimums)
# ...
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0        9.085       9.122       8824.       9.100
# 1        7.122      7.306*       1239.       7.194
# 2        7.031       7.362       1131.      7.161*
# 3        7.035       7.512       1136.       7.223
# 4        7.026       7.650       1125.       7.272
# 5        7.047       7.818       1150.       7.351
# 6        7.038       7.956       1140.       7.400
# 7       6.981*       8.046      1077.*       7.401
# 8        7.006       8.218       1105.       7.484
# 9        7.053       8.411       1158.       7.588
# 10       7.069       8.575       1178.       7.663
# 11       7.100       8.752       1216.       7.752
# 12       7.152       8.951       1281.       7.861
# 13       7.152       9.098       1283.       7.919
# 14       7.157       9.249       1290.       7.982
# ...

# %% [markdown]
# ### 6. Estimacion del modelo VAR(p)

# %%
var_result = model.fit(7)
print(var_result.summary())
# Out:
#    Summary of Regression Results
# ...
# Model:                          VAR
# Method:                         OLS
# Date:           sáb, 25, abr., 2026
# Time:                      12:21:39
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                    8.03778
# Nobs:                     455.000    HQIC:                   7.40116
# Log likelihood:          -4056.09    FPE:                    1083.57
# AIC:                      6.98733    Det(Omega_mle):         846.298
# --------------------------------------------------------------------
# Results for equation asma
# ...
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                    1.397592         3.167396            0.441           0.659
# L1.asma                  0.241371         0.046663            5.173           0.000
# ...

# %% [markdown]
# ### 7. Diagnostico de residuos
#
# Se verifica:
# 1. **Prueba de Portmanteau** (no autocorrelacion): H₀ = residuos no autocorrelacionados.
# 2. **Prueba de Jarque-Bera** (normalidad multivariada): H₀ = residuos normales.
# 3. **Graficos** de residuos y Q-Q plots.

# %%
port = var_result.test_whiteness(nlags=20, signif=0.05)
print('Prueba de No Autocorrelacion (Portmanteau):')
print(port.summary())
# Out:
# Prueba de No Autocorrelacion (Portmanteau):
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 20 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ...
# Test statistic Critical value p-value  df
# -----------------------------------------
#          239.3          242.6   0.067 208
# -----------------------------------------

# %%
norm = var_result.test_normality()
print('Prueba de Normalidad (Jarque-Bera multivariado):')
print(norm.summary())
# Out:
# Prueba de Normalidad (Jarque-Bera multivariado):
# normality (skew and kurtosis) test. H_0: data generated by normally-distributed process. Conclusion: reject H_0 at 5% significance level.
# ...
# Test statistic Critical value p-value df
# ----------------------------------------
#          3043.          15.51   0.000  8
# ----------------------------------------

# %%
resid = var_result.resid
col_labels_map = {
    'asma': 'Asma', 'pm25': 'PM2.5',
    'temperatura': 'Temperatura', 'precipitacion': 'Precipitacion'
}

fig, axes = plt.subplots(4, 2, figsize=(14, 12))
for i, (col, label) in enumerate(col_labels_map.items()):
    r = resid[col]
    axes[i, 0].plot(resid.index, r, linewidth=0.7, color='steelblue', alpha=0.8)
    axes[i, 0].axhline(0, color='red', linewidth=1, linestyle='--')
    axes[i, 0].set_title(f'Residuos -- {label}', fontsize=10)
    axes[i, 0].set_ylabel('Residuo')
    stats.probplot(r, plot=axes[i, 1])
    axes[i, 1].set_title(f'Q-Q -- {label}', fontsize=10)

plt.suptitle('Diagnostico de Residuos del VAR', fontsize=12, y=1.01, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. Causalidad de Granger
#
# Evalua si las variables ambientales (PM2.5, temperatura, precipitacion)
# ayudan a predecir los casos de asma en el sentido de Granger.
#
# - H₀: la variable X **no** causa en el sentido de Granger a Asma.
# - Se rechaza H₀ si p-valor < 0.05.

# %%
print('=' * 60)
print('  PRUEBAS DE CAUSALIDAD DE GRANGER  -->  Asma')
print('=' * 60)
causantes = {'pm25': 'PM2.5', 'temperatura': 'Temperatura', 'precipitacion': 'Precipitacion'}
for var, nombre in causantes.items():
    res = var_result.test_causality(causing=var, caused='asma', kind='f')
    decision = 'Si causa (rechaza H0)' if res.pvalue < 0.05 else 'No causa (no rechaza H0)'
    print(f'\n  {nombre} --> Asma')
    print(f'    F-estadistico : {res.test_statistic:.4f}')
    print(f'    p-valor       : {res.pvalue:.4f}')
    print(f'    Conclusion    : {decision}')
print('=' * 60)
# Out:
# ...
#   PRUEBAS DE CAUSALIDAD DE GRANGER  -->  Asma
# ...
#
#   PM2.5 --> Asma
#     F-estadistico : 0.7938
#     p-valor       : 0.5924
#     Conclusion    : No causa (no rechaza H0)
#
#   Temperatura --> Asma
#     F-estadistico : 0.7911
#     p-valor       : 0.5948
#     Conclusion    : No causa (no rechaza H0)
#
#   Precipitacion --> Asma
#     F-estadistico : 1.7006
#     p-valor       : 0.1046
#     Conclusion    : No causa (no rechaza H0)
# ...

# %% [markdown]
# ### 9. Funciones de Impulso-Respuesta (FIR)
#
# Se analiza la respuesta de los **casos de asma** ante un choque de una desviacion estandar en cada variable del sistema. Las bandas sombreadas representan el IC al 95%.

# %%
irf = var_result.irf(periods=20)
col_list = list(df.columns)
resp_idx = col_list.index('asma')

impulsos = [
    ('asma',          'Asma --> Asma',          'steelblue'),
    ('pm25',          'PM2.5 --> Asma',          'firebrick'),
    ('temperatura',   'Temperatura --> Asma',    'darkorange'),
    ('precipitacion', 'Precipitacion --> Asma',  'seagreen'),
]

fig, axes = plt.subplots(1, 4, figsize=(16, 4), sharey=False)
horizonte = np.arange(21)

for ax, (impulso, titulo, color) in zip(axes, impulsos):
    imp_idx  = col_list.index(impulso)
    irf_vals = irf.orth_irfs[:, resp_idx, imp_idx]
    stderr   = irf.stderr(orth=True)[:, resp_idx, imp_idx]
    ax.plot(horizonte, irf_vals, color=color, linewidth=2)
    ax.axhline(0, color='black', linewidth=0.8, linestyle='--')
    ax.fill_between(horizonte,
                    irf_vals - 1.96 * stderr,
                    irf_vals + 1.96 * stderr,
                    alpha=0.20, color=color)
    ax.set_title(titulo, fontsize=9)
    ax.set_xlabel('Horizonte (dias)')

axes[0].set_ylabel('Respuesta -- Asma')
fig.suptitle('Funciones de Impulso-Respuesta Ortogonales', fontsize=12,
             y=1.02, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. Descomposicion de la Varianza del Error de Pronostico (FEVD)
#
# Muestra que fraccion de la varianza de cada variable se explica por choques propios y externos.

# %%
fevd = var_result.fevd(periods=20)
col_list   = list(df.columns)
col_labels = ['Asma', 'PM2.5', 'Temperatura', 'Precipitacion']
colores_fevd = ['steelblue', 'firebrick', 'darkorange', 'seagreen']

fig, axes = plt.subplots(2, 2, figsize=(13, 9))
for ax_i, (resp_col, resp_label) in enumerate(zip(col_list, col_labels)):
    ax = axes[ax_i // 2][ax_i % 2]
    resp_idx = col_list.index(resp_col)
    fevd_data = pd.DataFrame(fevd.decomp[resp_idx], columns=col_labels)
    fevd_data.plot(kind='area', stacked=True, ax=ax,
                  alpha=0.75, color=colores_fevd, legend=True)
    ax.set_title(f'FEVD -- {resp_label}', fontsize=11, fontweight='bold')
    ax.set_xlabel('Horizonte (dias)')
    ax.set_ylabel('Proporcion de varianza')
    ax.set_ylim(0, 1)
    ax.legend(fontsize=8, loc='upper right')

fig.suptitle('Descomposicion del Error de Pronostico (FEVD)',
             fontsize=13, y=1.01, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. Pronostico fuera de muestra
#
# Se usa **validacion temporal**: los ultimos 30 dias como conjunto de prueba.
# Se generan intervalos de confianza al 95%.

# %%
n_test   = 30
train_df = df.iloc[:-n_test]
test_df  = df.iloc[-n_test:]

model_train = VAR(train_df).fit(p_opt)
fc_vals     = model_train.forecast(y=train_df.values[-p_opt:], steps=n_test)
fc_ci       = model_train.forecast_interval(y=train_df.values[-p_opt:], steps=n_test, alpha=0.05)
fc_df    = pd.DataFrame(fc_vals,   index=test_df.index, columns=df.columns)
fc_lower = pd.DataFrame(fc_ci[1],  index=test_df.index, columns=df.columns)
fc_upper = pd.DataFrame(fc_ci[2],  index=test_df.index, columns=df.columns)

# Grafico
fig, ax = plt.subplots(figsize=(13, 5))
ventana = 90
ax.plot(train_df.index[-ventana:], train_df['asma'].iloc[-ventana:],
        label='Entrenamiento', color='steelblue', linewidth=1)
ax.plot(test_df.index, test_df['asma'],
        label='Observado (test)', color='black', linewidth=1.5)
ax.plot(fc_df.index, fc_df['asma'],
        label='Pronostico VAR', color='firebrick', linewidth=1.8, linestyle='--')
ax.fill_between(fc_df.index, fc_lower['asma'], fc_upper['asma'],
                alpha=0.20, color='firebrick', label='IC 95%')
ax.axvline(test_df.index[0], color='gray', linestyle=':', linewidth=1.2)
ax.set_title('Pronostico de Casos de Asma -- Ultimos 30 dias',
             fontsize=12, fontweight='bold')
ax.set_xlabel('Fecha')
ax.set_ylabel('Casos diarios de asma')
ax.legend()
plt.tight_layout()
plt.show()

# Metricas
mae  = np.mean(np.abs(test_df['asma'] - fc_df['asma']))
rmse = np.sqrt(np.mean((test_df['asma'] - fc_df['asma'])**2))
mape = np.mean(np.abs((test_df['asma'] - fc_df['asma']) /
               test_df['asma'].replace(0, np.nan))) * 100
print('Metricas de pronostico -- Asma (30 dias):')
print(f'  MAE  : {mae:.2f} casos')
print(f'  RMSE : {rmse:.2f} casos')
print(f'  MAPE : {mape:.1f} %')
# Out:
# Metricas de pronostico -- Asma (30 dias):
#   MAE  : 2.62 casos
#   RMSE : 3.57 casos
#   MAPE : 63.6 %

# %% [markdown]
# ### Conclusiones
#
# 1. **Estacionariedad**: Las cuatro series son estacionarias en niveles (ADF + KPSS confirman), por lo que no se requiere diferenciar antes de ajustar el VAR.
# 2. **Orden del modelo**: El criterio BIC selecciona el rezago optimo (parsimonia); AIC tiende a sobreajustar con rezagos altos.
# 3. **Causalidad de Granger**: Indica si PM2.5, temperatura y precipitacion mejoran estadisticamente la prediccion de casos de asma.
# 4. **Impulso-Respuesta**: Cuantifica el efecto dinamico de un choque ambiental sobre los casos de asma a lo largo del tiempo.
# 5. **FEVD**: Revela la importancia relativa de cada variable en la varianza del error de pronostico.
# 6. **Pronostico**: El VAR genera predicciones conjuntas con intervalos de confianza al 95% para los proximos periodos.
