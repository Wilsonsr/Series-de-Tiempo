# %% [markdown]
# <div style="text-align: center; color:rgb(0, 0, 0); font-family: Arial, sans-serif; background-color:rgb(137, 200, 129); padding: 10px; border-radius: 10px; box-shadow: 0 4px 8px rgba(0, 0, 0, 1.2); line-height: 0.1;">
#
# ### **Series de Tiempo**
# #### **Universidad Central**
# #### Maestría en Analítica de Datos
# #### Docente: Wilson Sandoval Rodriguez
# ##### wsandovalr@ucentral.edu.co
#
# </div>

# %% [markdown]
# Cuando desarrollamos un modelo para predecir valores futuros (por ejemplo, ventas, temperatura, demanda, etc.), necesitamos saber qué tan bien está funcionando ese modelo. Evaluar nos permite:
#
# Ver si el modelo aprendió los patrones correctos.
# Comparar entre varios modelos para elegir el mejor.
# Detectar sobreajuste (cuando el modelo aprende muy bien los datos del pasado, pero falla en el futuro).

# %% [markdown]
# ###  📏 Criterios de Evaluación de Modelos de Series de Tiempo
#
# ###  **MAE – Mean Absolute Error**
# - Mide el promedio de los errores absolutos.
# - Más robusto a valores atípicos que el RMSE.
#
# $$
# MAE = \frac{1}{n} \sum_{t=1}^{n} |Y_t - \hat{Y}_t|
# $$
# Donde:
# -  $Y_t$ es el valor real en el tiempo $ t $.
# -  $\hat{Y}_t$ es el valor pronosticado en el tiempo $t$.
# - $n$ es el número total de observaciones.
#
# - **Ventajas:** El MAE es simple y fácil de interpretar, ya que el error medio se expresa en las mismas unidades que los datos originales. Es menos sensible a los valores atípicos en comparación con otras métricas de error, como el error cuadrático medio (EMM).
#
# - **Desventajas:** El MAE no distingue entre sobreestimación y subestimación, y no proporciona información sobre la dirección o magnitud de los errores individuales. Además, dependiendo del problema específico, puede considerarse una desventaja que no penalice las predicciones erróneas tanto como el MSE.

# %% [markdown]
# ###  **MSE (Mean Squared Error)**
# $$
# MSE = \frac{1}{n} \sum_{t=1}^{n} (Y_t - \hat{Y}_t)^2
# $$
# Donde:
# - $Y_t$ es el valor real en el tiempo $t$.
# - $\hat{Y}_t$ es el valor pronosticado en el tiempo $t$.
# - $n$ es el número total de observaciones.
#
# - **Ventajas :** su simplicidad y capacidad para capturar errores grandes y pequeños. Penaliza los errores grandes debidos al cuadrado.
#
# - **Desventajas :** Se enfatizan los grandes errores debidos al cuadrado, lo cual puede ser una desventaja cuando hay valores atípicos. Además, no es fácil de interpretar, ya que se expresa en unidades cuadradas de los datos. Otras métricas, como el Error Medio Absoluto (EMA) o el Error Cuadrático Medio (RMSE), pueden ser preferibles en ciertas situaciones donde la interpretabilidad es un requisito. Además, no distingue entre sobreestimación y subestimación.

# %% [markdown]
# ###  **RMSE – Root Mean Squared Error**
# - Mide la raíz cuadrada del promedio de los errores al cuadrado.
# - Penaliza más los errores grandes.
# - **Fórmula:**
#
#
# $$
# RMSE = \sqrt{\frac{1}{n} \sum_{t=1}^{n} (Y_t - \hat{Y}_t)^2}
# $$
# Donde:
# - $Y_t$ es el valor real en el tiempo $t$.
# - $\hat{Y}_t$ es el valor pronosticado en el tiempo $t$.
# - $n$ es el número total de observaciones.
#
#
# - **Ventajas :** penaliza grandes errores debidos al cuadrado y es fácilmente interpretable gracias a expresar el número en la magnitud de las variables.
# - **Desventajas :** Es sensible a valores atípicos y puede verse sesgado por valores extremos. Además, el RMSE no proporciona información sobre la dirección ni el patrón de los errores de pronóstico, ni distingue entre sobrepredicciones y subpredicciones.

# %% [markdown]
# ###  **MAPE (Mean Absolute Percentage Error)**
#
# - Error porcentual medio.
# - No usar si hay ceros en la serie real.
#
#
# $$
# MAPE = \frac{100}{n} \sum_{t=1}^{n} \left| \frac{Y_t - \hat{Y}_t}{Y_t} \right|
# $$
# Donde:
# - $Y_t$ es el valor real en el tiempo \( t \).
# -  $\hat{Y}_t$ es el valor pronosticado en el tiempo $t$.
# - $n$ es el número total de observaciones.
#
# - **Ventajas:** su capacidad de interpretar errores en términos de porcentaje, lo que facilita su comprensión y comparación entre diferentes conjuntos de datos.
# - **Desventajas :** Es sensible a valores extremos y no puede manejar valores reales cero o casi cero, ya que no es posible dividir por cero. MAPE trata las sobreestimaciones y subestimaciones de forma diferente, lo que significa que no es una métrica simétrica. La dirección del error (si la predicción es superior o inferior al valor real) afecta el valor de MAPE. Esta falta de simetría significa que podría no ser adecuado para situaciones donde las sobreestimaciones y subestimaciones tienen diferentes implicaciones o costos.

# %% [markdown]
# ###  **SMAPE – Symmetric Mean Absolute Percentage Error**
# - Versión simétrica del MAPE. Más estable cuando hay valores cercanos a cero.
# $$
#
# SMAPE = \frac{100\%}{n} \sum_{t=1}^{n} \frac{ |y_t - \hat{y}_t| }{ (|y_t| + |\hat{y}_t|)/2 }
#
# $$
#
#
# - **Ventajas :** su capacidad para manejar valores cero y su simetría, que garantiza que los errores de sobreestimación y subestimación se traten por igual.
# - **Desventajas :** Es sensible a valores atípicos extremos, ya que se calcula la diferencia porcentual. Puede generar valores infinitos si tanto el valor real como el predicho son cero.

# %% [markdown]
# ### 🧠 Criterios de Información
#
# ###  **AIC – Akaike Information Criterion**
# - Penaliza modelos con más parámetros.
# - Menor AIC → mejor modelo.
# - **Fórmula:**
#
# $$
# AIC = 2k - 2 \ln(\hat{L})
# $$
#
# Donde:
# -  $k$: número de parámetros
# - $\hat{L}$: máxima verosimilitud del modelo
#
#
#
# ###  **BIC – Bayesian Information Criterion**
# - Similar al AIC pero con penalización mayor.
# - **Fórmula:**
#
# $$
# BIC = k \ln(n) - 2 \ln(\hat{L})
# $$

# %% [markdown]
# ###  📉 Evaluación de Residuos
#
# ###  **Test de Ljung-Box**
# - Revisa si los residuos están autocorrelacionados.
# - Hipótesis nula: residuos son ruido blanco.
# - Se espera un **p-valor alto** (no autocorrelación significativa).
#
#
# ###  **Autocorrelación (ACF/PACF) de residuos**
# - Se grafican para verificar independencia.
# - Los residuos ideales no deben mostrar autocorrelación significativa.
#
#
# ###  **Análisis visual de residuos**
# - Gráficos para observar:
#   - Si los residuos están centrados en cero.
#   - Si la varianza es constante.
#   - Si hay patrones no capturados por el modelo.

# %% [markdown]
# ## 🔁 Validación temporal
#
# ### **Validación cruzada para series de tiempo**
# - **No se debe mezclar aleatoriamente** como en ML tradicional.
# - Métodos más comunes:
#   - **Ventana creciente (expanding window)**
#   - **Ventana deslizante (sliding window)**
#   - **Walk-forward validation**

# %% [markdown]
# ## 🎯 Recomendaciones
#
# | **Criterio**        | **¿Cuándo usar?**               | **Ventajas**                                | **Limitaciones**                             |
# |---------------------|----------------------------------|---------------------------------------------|----------------------------------------------|
# | **MAE**             | Errores promedio                | Intuitivo, fácil de interpretar              | No penaliza fuerte errores grandes           |
# | **RMSE**            | Cuando importan los errores grandes | Penaliza errores severos                 | Sensible a outliers                          |
# | **MAPE**            | Comparación porcentual          | Escalable y fácil de explicar                | Problemas con ceros                          |
# | **SMAPE**           | Alternativa a MAPE              | Evita divisiones por cero                    | Difícil de interpretar                       |
# | **MASE**            | Comparación entre series        | Escalable, robusto                           | Requiere cálculo base naive                 |
# | **AIC / BIC**       | Comparar modelos estadísticos   | Considera ajuste y complejidad               | Solo para modelos con verosimilitud          |
# | **Ljung-Box**       | Diagnóstico de residuos         | Detecta autocorrelación                      | No compara modelos                           |
# | **Validación cruzada** | Predicción futura realista   | Generaliza mejor                             | Más costosa computacionalmente               |

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
# !pip install meteostat
# Out:
# Requirement already satisfied: meteostat in /usr/local/lib/python3.11/dist-packages (1.6.8)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.11/dist-packages (from meteostat) (2.2.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from meteostat) (2025.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from meteostat) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1->meteostat) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1->meteostat) (1.17.0)

# %%
# Importar librerías
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily, Monthly, Hourly
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, root_mean_squared_error
# Establecer el período de tiempo
start = datetime(2018, 6, 1)
end = datetime(2024, 12, 31)

# Crear el punto geográfico para Bogotá, Colombia
# Coordenadas aproximadas: Latitud 4.7110, Longitud -74.0721, Altitud 2640 msnm
bogota = Point(4.7110, -74.0721, 2640)

# Obtener datos diarios
data = Monthly(bogota, start, end)
data = data.fetch()

# %%
# Graficar temperaturas promedio, mínima y máxima
data.plot(y=['tavg', 'tmin', 'tmax'], title='Temperatura diaria en Bogotá (2018)')
plt.xlabel('Fecha')
plt.ylabel('Temperatura (°C)')
plt.grid(True)
plt.show()

# %%
data
# Out:
#             tavg  tmin  tmax   prcp  wspd    pres  tsun
# time
# 2018-06-01  13.4   9.0  18.2    NaN   NaN     NaN   NaN
# 2018-07-01  13.3   9.2  18.4    NaN  11.5     NaN   NaN
# 2018-08-01  13.1   8.0  18.4    NaN  12.6  1017.1   NaN
# 2018-09-01  13.4   8.1  19.3    NaN  10.2  1015.6   NaN
# 2018-10-01  13.6   9.0  19.6    NaN   9.2  1016.2   NaN
# ...          ...   ...   ...    ...   ...     ...   ...
# 2024-08-01  13.6   7.1  19.4    NaN  11.3     NaN   NaN
# 2024-09-01  14.2   8.0  20.0    NaN  11.8     NaN   NaN
# 2024-10-01  13.9   8.1  19.8  157.2  10.1  1018.4   NaN
# 2024-11-01  13.4   9.2  18.9  467.5   8.7  1020.7   NaN
# 2024-12-01  13.6   7.9  20.2    NaN   9.5     NaN   NaN
#
# [79 rows x 7 columns]

# %%
data["tmax"].plot(title='Temperatura máxima diaria en Bogotá (2018)')
# Out:
# <Axes: title={'center': 'Temperatura máxima diaria en Bogotá (2018)'}, xlabel='time'>

# %%
# Temperatura máxima
df_temp_max = data[['tmax']]

# Visualizar la data
df_temp_max.plot(figsize=(10,5))
plt.grid(alpha=0.5)
plt.xlabel('Fecha')
plt.ylabel('Temperature (°C)')
plt.show()

# %%
df_temp_max.isna().sum()
# Out:
# tmax    0
# dtype: int64

# %%
import statsmodels.api as sm


decomposition = sm.tsa.seasonal_decompose(df_temp_max,
                                          model='additive',
                                          period=12)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot the decomposed components
decomposition.plot()
plt.show()

# %%
# entrenamiento y prueba de datos
df_train = df_temp_max.loc[:'2023-12-31']
df_test = df_temp_max.loc['2024-01-01':]


ax = df_train[:].plot(figsize=(10, 5))
df_test.plot(ax=ax)
plt.legend(['Train', 'Test'])
plt.xlabel('Fecha')
plt.ylabel('Temperatura (°C)')
plt.show()

# %%
df_train
# Out:
#             tmax
# time
# 2018-06-01  18.2
# 2018-07-01  18.4
# 2018-08-01  18.4
# 2018-09-01  19.3
# 2018-10-01  19.6
# ...          ...
# 2023-08-01  19.1
# 2023-09-01  19.5
# 2023-10-01  19.9
# 2023-11-01  19.4
# 2023-12-01  19.9
#
# [67 rows x 1 columns]

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
modelo_1=ARIMA(df_train,order=(1,1,1), seasonal_order=(0,1,1,12)).fit()
# Out:
# UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.

# %%
modelo_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                     SARIMAX Results
# ========================================================================================
# Dep. Variable:                             tmax   No. Observations:                   67
# Model:             ARIMA(1, 1, 1)x(0, 1, 1, 12)   Log Likelihood                 -46.716
# Date:                          Sat, 22 Mar 2025   AIC                            101.432
# Time:                                  04:35:01   BIC                            109.388
# Sample:                              06-01-2018   HQIC                           104.501
#                                    - 12-01-2023
# Covariance Type:                            opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5959      0.146      4.079      0.000       0.310       0.882
# ma.L1         -0.9996     16.096     -0.062      0.950     -32.546      30.547
# ma.S.L12      -0.9974     31.573     -0.032      0.975     -62.879      60.884
# sigma2         0.2105      7.604      0.028      0.978     -14.693      15.114
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                 0.40
# Prob(Q):                              0.83   Prob(JB):                         0.82
# Heteroskedasticity (H):               2.68   Skew:                            -0.17
# Prob(H) (two-sided):                  0.04   Kurtosis:                         2.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df_train
# Out:
#             tmax
# time
# 2018-06-01  18.2
# 2018-07-01  18.4
# 2018-08-01  18.4
# 2018-09-01  19.3
# 2018-10-01  19.6
# ...          ...
# 2023-08-01  19.1
# 2023-09-01  19.5
# 2023-10-01  19.9
# 2023-11-01  19.4
# 2023-12-01  19.9
#
# [67 rows x 1 columns]

# %%
#hacer predicciones
forecast_results = modelo_1.predict(start=df_test.index[0], end=df_test.index[-1], typ='levels')


forecast_values_auto = forecast_results  # Now this is a Series with an index
confidence_intervals_auto = modelo_1.get_forecast(steps=len(df_test)).conf_int() # Get confidence intervals

# Plot forecast
ax = df_train[-60:].plot(figsize=(10,5))
forecast_results.plot(ax=ax, label='Forecast max temp')
df_test.plot(ax=ax, label='Actual max temp')

#df_test.plot(ax=ax)  
plt.fill_between(forecast_values_auto.index,
                 confidence_intervals_auto.iloc[:, 0],  
                 confidence_intervals_auto.iloc[:, 1],  
                 color='blue',
                 alpha=0.15)
plt.legend(['Training max temp',
            'Forecast max temp',
            'Actual max temp'],
           loc='upper left')
plt.xlabel('Date')
plt.ylabel('Maximum temperature')
plt.grid(alpha=0.5)
plt.show()
# Out:
# FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.

# %%
df_test
# Out:
#             tmax
# time
# 2024-01-01  20.3
# 2024-02-01  20.6
# 2024-03-01  20.2
# 2024-04-01  20.6
# 2024-05-01  19.1
# 2024-06-01  18.8
# 2024-07-01  18.8
# 2024-08-01  19.4
# 2024-09-01  20.0
# 2024-10-01  19.8
# 2024-11-01  18.9
# 2024-12-01  20.2

# %%
forecast_values_auto
# Out:
# 2024-01-01    19.756244
# 2024-02-01    20.021773
# 2024-03-01    19.081649
# 2024-04-01    19.204893
# 2024-05-01    19.101427
# 2024-06-01    18.479321
# 2024-07-01    18.442365
# 2024-08-01    18.590045
# 2024-09-01    19.038364
# 2024-10-01    19.103555
# 2024-11-01    19.185188
# 2024-12-01    19.666174
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, root_mean_squared_error
import numpy as np


actual_values = df_test.values.flatten()


# MAE – Mean Absolute Error
mae = mean_absolute_error(actual_values, forecast_values_auto)
print("MAE:", mae)

# RMSE – Root Mean Squared Error
rmse = root_mean_squared_error(actual_values, forecast_values_auto)
print("RMSE:", rmse)

# MAPE – Mean Absolute Percentage Error
mape = mean_absolute_percentage_error(actual_values, forecast_values_auto) * 100
print("MAPE (%):", mape)
# Out:
# MAE: 0.6335192526450703
# RMSE: 0.7354079830660427
# MAPE (%): 3.1718368038484197

# %%
df_train
# Out:
#             tmax
# time
# 2018-06-01  18.2
# 2018-07-01  18.4
# 2018-08-01  18.4
# 2018-09-01  19.3
# 2018-10-01  19.6
# ...          ...
# 2023-08-01  19.1
# 2023-09-01  19.5
# 2023-10-01  19.9
# 2023-11-01  19.4
# 2023-12-01  19.9
#
# [67 rows x 1 columns]

# %% [markdown]
# modelos de suavizamiento

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, Holt, ExponentialSmoothing

hw_model = ExponentialSmoothing(df_train, trend='add', seasonal='add', seasonal_periods=12).fit()
hw_forecast = hw_model.forecast(steps=12)

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(df_train.index, df_train, label='Train')
ax.plot(df_test.index, df_test, label='Test')
ax.plot(df_test.index, hw_forecast, label='Holt-Winters forecast')

plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid(alpha=0.5)

# %%
hw_forecast
# Out:
# 2024-01-01    19.888944
# 2024-02-01    20.208939
# 2024-03-01    19.308956
# 2024-04-01    19.468963
# 2024-05-01    19.408988
# 2024-06-01    18.833984
# 2024-07-01    18.800650
# 2024-08-01    18.950651
# 2024-09-01    19.400621
# 2024-10-01    19.467289
# 2024-11-01    19.550566
# 2024-12-01    20.033887
# Freq: MS, dtype: float64

# %%
actual_values = df_test.values.flatten()

# MAE – Mean Absolute Error
mae = mean_absolute_error(actual_values, hw_forecast)
print("MAE:", mae)

# RMSE – Root Mean Squared Error
rmse = root_mean_squared_error(actual_values, hw_forecast)
print("RMSE:", rmse)

# MAPE – Mean Absolute Percentage Error
mape = mean_absolute_percentage_error(actual_values, hw_forecast) * 100
print("MAPE (%):", mape)
# Out:
# MAE: 0.4471615028360582
# RMSE: 0.5488187584647229
# MAPE (%): 2.240398141587353

# %% [markdown]
# # Modelo 3

# %%
import pandas as pd
import numpy as np
from prophet import Prophet
from prophet.plot import add_changepoints_to_plot, plot_cross_validation_metric
from prophet.diagnostics import cross_validation, performance_metrics

#  Preparar datos para Prophet


df_train = df_train.reset_index()
df_train.columns = ['ds', 'y']  # Prophet requiere estas columnas

# %%
df_train
# Out:
#            ds     y
# 0  2018-06-01  18.2
# 1  2018-07-01  18.4
# 2  2018-08-01  18.4
# 3  2018-09-01  19.3
# 4  2018-10-01  19.6
# ..        ...   ...
# 62 2023-08-01  19.1
# 63 2023-09-01  19.5
# 64 2023-10-01  19.9
# 65 2023-11-01  19.4
# 66 2023-12-01  19.9
#
# [67 rows x 2 columns]

# %%
# Crear y ajustar el modelo Prophet
model_3 = Prophet(seasonality_mode='additive', yearly_seasonality=True, daily_seasonality=False, weekly_seasonality=False)
model_3.fit(df_train)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjthubo_5/_p66xvb8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjthubo_5/ag85whjt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54087', 'data', 'file=/tmp/tmpjthubo_5/_p66xvb8.json', 'init=/tmp/tmpjthubo_5/ag85whjt.json', 'output', 'file=/tmp/tmpjthubo_5/prophet_modelmg0u_61r/prophet_model-20250322043504.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 04:35:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:35:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Crear un marco de datos futuro para la predicción
future = model_3.make_future_dataframe(periods=12,freq='MS')

# Pronosticar los valores futuros del marco de datos
forecast = model_3.predict(future)

# Verifique los valores pronosticados y el pronóstico del límite
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#            ds       yhat  yhat_lower  yhat_upper
# 0  2018-06-01  18.802556   18.262670   19.379073
# 1  2018-07-01  18.779638   18.197070   19.358759
# 2  2018-08-01  18.916624   18.379690   19.458193
# 3  2018-09-01  19.405995   18.838846   19.966656
# 4  2018-10-01  19.470232   18.878528   20.044243
# ..        ...        ...         ...         ...
# 74 2024-08-01  19.120452   18.566035   19.645173
# 75 2024-09-01  19.268159   18.734680   19.833465
# 76 2024-10-01  19.501095   18.955446   20.081104
# 77 2024-11-01  19.622158   19.055717   20.171862
# 78 2024-12-01  20.365465   19.798441   20.910621
#
# [79 rows x 4 columns]

# %%
forecast
# Out:
#            ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0  2018-06-01  19.693104   18.262670   19.379073    19.693104    19.693104
# 1  2018-07-01  19.698861   18.197070   19.358759    19.698861    19.698861
# 2  2018-08-01  19.704809   18.379690   19.458193    19.704809    19.704809
# 3  2018-09-01  19.710757   18.838846   19.966656    19.710757    19.710757
# 4  2018-10-01  19.716514   18.878528   20.044243    19.716514    19.716514
# ..        ...        ...         ...         ...          ...          ...
# 74 2024-08-01  19.713448   18.566035   19.645173    19.681910    19.746244
# 75 2024-09-01  19.732485   18.734680   19.833465    19.693601    19.772098
# 76 2024-10-01  19.750908   18.955446   20.081104    19.704665    19.799032
# 77 2024-11-01  19.769944   19.055717   20.171862    19.716121    19.824794
# 78 2024-12-01  19.788367   19.798441   20.910621    19.727323    19.850830
#
#     additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0        -0.890548             -0.890548             -0.890548 -0.890548
# 1        -0.919222             -0.919222             -0.919222 -0.919222
# 2        -0.788185             -0.788185             -0.788185 -0.788185
# 3        -0.304762             -0.304762             -0.304762 -0.304762
# 4        -0.246282             -0.246282             -0.246282 -0.246282
# ..             ...                   ...                   ...       ...
# 74       -0.592996             -0.592996             -0.592996 -0.592996
# 75       -0.464326             -0.464326             -0.464326 -0.464326
# 76       -0.249812             -0.249812             -0.249812 -0.249812
# 77       -0.147786             -0.147786             -0.147786 -0.147786
# 78        0.577098              0.577098              0.577098  0.577098
#
#     yearly_lower  yearly_upper  multiplicative_terms  \
# 0      -0.890548     -0.890548                   0.0
# 1      -0.919222     -0.919222                   0.0
# 2      -0.788185     -0.788185                   0.0
# 3      -0.304762     -0.304762                   0.0
# 4      -0.246282     -0.246282                   0.0
# ..           ...           ...                   ...
# 74     -0.592996     -0.592996                   0.0
# 75     -0.464326     -0.464326                   0.0
# 76     -0.249812     -0.249812                   0.0
# 77     -0.147786     -0.147786                   0.0
# 78      0.577098      0.577098                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper       yhat
# 0                          0.0                         0.0  18.802556
# 1                          0.0                         0.0  18.779638
# 2                          0.0                         0.0  18.916624
# 3                          0.0                         0.0  19.405995
# 4                          0.0                         0.0  19.470232
# ..                         ...                         ...        ...
# 74                         0.0                         0.0  19.120452
# 75                         0.0                         0.0  19.268159
# 76                         0.0                         0.0  19.501095
# 77                         0.0                         0.0  19.622158
# 78                         0.0                         0.0  20.365465
#
# [79 rows x 16 columns]

# %%
future
# Out:
#            ds
# 0  2018-06-01
# 1  2018-07-01
# 2  2018-08-01
# 3  2018-09-01
# 4  2018-10-01
# ..        ...
# 74 2024-08-01
# 75 2024-09-01
# 76 2024-10-01
# 77 2024-11-01
# 78 2024-12-01
#
# [79 rows x 1 columns]

# %%
df_test.reset_index(inplace=True)

# %%
df_test
# Out:
#          time  tmax
# 0  2024-01-01  20.3
# 1  2024-02-01  20.6
# 2  2024-03-01  20.2
# 3  2024-04-01  20.6
# 4  2024-05-01  19.1
# 5  2024-06-01  18.8
# 6  2024-07-01  18.8
# 7  2024-08-01  19.4
# 8  2024-09-01  20.0
# 9  2024-10-01  19.8
# 10 2024-11-01  18.9
# 11 2024-12-01  20.2

# %%
# Cambiar el nombre de la fecha a ds y cerrar el precio a y
df_test.rename(columns={'time': 'ds', 'tmax': 'y'}, inplace=True)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Visualizar el pronostico
fig = model_3.plot(forecast)
ax = fig.gca()
ax.plot( df_test["ds"], df_test["y"], 'g.')

# %%
# Visualizar las componentes
model_3.plot_components(forecast);

# %%
fig = model_3.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), model_3, forecast)

# %%
future
# Out:
#            ds
# 0  2018-06-01
# 1  2018-07-01
# 2  2018-08-01
# 3  2018-09-01
# 4  2018-10-01
# ..        ...
# 74 2024-08-01
# 75 2024-09-01
# 76 2024-10-01
# 77 2024-11-01
# 78 2024-12-01
#
# [79 rows x 1 columns]

# %%
forecast
# Out:
#            ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0  2018-06-01  19.693104   18.262670   19.379073    19.693104    19.693104
# 1  2018-07-01  19.698861   18.197070   19.358759    19.698861    19.698861
# 2  2018-08-01  19.704809   18.379690   19.458193    19.704809    19.704809
# 3  2018-09-01  19.710757   18.838846   19.966656    19.710757    19.710757
# 4  2018-10-01  19.716514   18.878528   20.044243    19.716514    19.716514
# ..        ...        ...         ...         ...          ...          ...
# 74 2024-08-01  19.713448   18.566035   19.645173    19.681910    19.746244
# 75 2024-09-01  19.732485   18.734680   19.833465    19.693601    19.772098
# 76 2024-10-01  19.750908   18.955446   20.081104    19.704665    19.799032
# 77 2024-11-01  19.769944   19.055717   20.171862    19.716121    19.824794
# 78 2024-12-01  19.788367   19.798441   20.910621    19.727323    19.850830
#
#     additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0        -0.890548             -0.890548             -0.890548 -0.890548
# 1        -0.919222             -0.919222             -0.919222 -0.919222
# 2        -0.788185             -0.788185             -0.788185 -0.788185
# 3        -0.304762             -0.304762             -0.304762 -0.304762
# 4        -0.246282             -0.246282             -0.246282 -0.246282
# ..             ...                   ...                   ...       ...
# 74       -0.592996             -0.592996             -0.592996 -0.592996
# 75       -0.464326             -0.464326             -0.464326 -0.464326
# 76       -0.249812             -0.249812             -0.249812 -0.249812
# 77       -0.147786             -0.147786             -0.147786 -0.147786
# 78        0.577098              0.577098              0.577098  0.577098
#
#     yearly_lower  yearly_upper  multiplicative_terms  \
# 0      -0.890548     -0.890548                   0.0
# 1      -0.919222     -0.919222                   0.0
# 2      -0.788185     -0.788185                   0.0
# 3      -0.304762     -0.304762                   0.0
# 4      -0.246282     -0.246282                   0.0
# ..           ...           ...                   ...
# 74     -0.592996     -0.592996                   0.0
# 75     -0.464326     -0.464326                   0.0
# 76     -0.249812     -0.249812                   0.0
# 77     -0.147786     -0.147786                   0.0
# 78      0.577098      0.577098                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper       yhat
# 0                          0.0                         0.0  18.802556
# 1                          0.0                         0.0  18.779638
# 2                          0.0                         0.0  18.916624
# 3                          0.0                         0.0  19.405995
# 4                          0.0                         0.0  19.470232
# ..                         ...                         ...        ...
# 74                         0.0                         0.0  19.120452
# 75                         0.0                         0.0  19.268159
# 76                         0.0                         0.0  19.501095
# 77                         0.0                         0.0  19.622158
# 78                         0.0                         0.0  20.365465
#
# [79 rows x 16 columns]

# %%
y_true=df_test["y"]

# %%
y_pred=forecast[["ds","yhat"]][67:]
y_pred
# Out:
#            ds       yhat
# 67 2024-01-01  19.734094
# 68 2024-02-01  20.810827
# 69 2024-03-01  19.770629
# 70 2024-04-01  19.777776
# 71 2024-05-01  19.193941
# 72 2024-06-01  18.714383
# 73 2024-07-01  18.704711
# 74 2024-08-01  19.120452
# 75 2024-09-01  19.268159
# 76 2024-10-01  19.501095
# 77 2024-11-01  19.622158
# 78 2024-12-01  20.365465

# %%
y_pred
# Out:
#            ds       yhat
# 67 2024-01-01  19.734094
# 68 2024-02-01  20.810827
# 69 2024-03-01  19.770629
# 70 2024-04-01  19.777776
# 71 2024-05-01  19.193941
# 72 2024-06-01  18.714383
# 73 2024-07-01  18.704711
# 74 2024-08-01  19.120452
# 75 2024-09-01  19.268159
# 76 2024-10-01  19.501095
# 77 2024-11-01  19.622158
# 78 2024-12-01  20.365465

# %%
# 5. Evaluar el modelo

mae = mean_absolute_error(y_true, y_pred["yhat"])
rmse = mean_squared_error(y_true, y_pred["yhat"])
mape = mean_absolute_percentage_error(y_true, y_pred["yhat"]) * 100

print("\n📊 Prophet")
print(f"MAE : {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# 📊 Prophet
# MAE : 0.38
# RMSE: 0.21
# MAPE: 1.89%

# %%
hw_forecast
# Out:
# 2024-01-01    19.888944
# 2024-02-01    20.208939
# 2024-03-01    19.308956
# 2024-04-01    19.468963
# 2024-05-01    19.408988
# 2024-06-01    18.833984
# 2024-07-01    18.800650
# 2024-08-01    18.950651
# 2024-09-01    19.400621
# 2024-10-01    19.467289
# 2024-11-01    19.550566
# 2024-12-01    20.033887
# Freq: MS, dtype: float64

# %%
y_pred
# Out:
#            ds       yhat
# 67 2024-01-01  19.734094
# 68 2024-02-01  20.810827
# 69 2024-03-01  19.770629
# 70 2024-04-01  19.777776
# 71 2024-05-01  19.193941
# 72 2024-06-01  18.714383
# 73 2024-07-01  18.704711
# 74 2024-08-01  19.120452
# 75 2024-09-01  19.268159
# 76 2024-10-01  19.501095
# 77 2024-11-01  19.622158
# 78 2024-12-01  20.365465

# %%
forecast_results
# Out:
# 2024-01-01    19.756244
# 2024-02-01    20.021773
# 2024-03-01    19.081649
# 2024-04-01    19.204893
# 2024-05-01    19.101427
# 2024-06-01    18.479321
# 2024-07-01    18.442365
# 2024-08-01    18.590045
# 2024-09-01    19.038364
# 2024-10-01    19.103555
# 2024-11-01    19.185188
# 2024-12-01    19.666174
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
df_test
# Out:
#            ds     y
# 0  2024-01-01  20.3
# 1  2024-02-01  20.6
# 2  2024-03-01  20.2
# 3  2024-04-01  20.6
# 4  2024-05-01  19.1
# 5  2024-06-01  18.8
# 6  2024-07-01  18.8
# 7  2024-08-01  19.4
# 8  2024-09-01  20.0
# 9  2024-10-01  19.8
# 10 2024-11-01  18.9
# 11 2024-12-01  20.2

# %%
df_test.set_index(df_test['ds'], inplace=True)

# %%
y_pred.set_index(y_pred['ds'], inplace=True)

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(hw_forecast.index, hw_forecast, label="Holt_Winters", marker="o")
ax.plot(forecast_results.index, forecast_results, label='ARIMA', marker="+")
ax.plot(df_test.index, df_test['y'], label='Actual', marker="*")
ax.plot(y_pred.index, y_pred['yhat'], label='Prophet', marker="s")

plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid(alpha=0.5)



ax.legend()
plt.title('Comparison of Forecast Methods')
plt.show()

# %%
df_temp_max.reset_index(inplace=True)

# %%
df_temp_max.rename(columns={'time': 'ds', 'tmax': 'y'}, inplace=True)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 
model_3 = Prophet(seasonality_mode='additive', yearly_seasonality=True, daily_seasonality=False, weekly_seasonality=False)  # Create a new Prophet object
model_3.fit(df_temp_max)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjthubo_5/l4cgjd4x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjthubo_5/cpv3flgs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67318', 'data', 'file=/tmp/tmpjthubo_5/l4cgjd4x.json', 'init=/tmp/tmpjthubo_5/cpv3flgs.json', 'output', 'file=/tmp/tmpjthubo_5/prophet_model38syhwuj/prophet_model-20250322045658.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 04:56:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:56:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
model_3.plot_components(model_3.predict(future))
